# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto=pd.read_csv('automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
#  16  fuel-system        201 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             197 non-null    float64
#  19  compression-ratio  201 non-null    float64
#  20  horsepower         201 non-null    float64
#  21  peak-rpm           201 non-null    float64
#  22  city-mpg           201 non-null    int64
#  23  highway-mpg        201 non-null    int64
#  24  price              201 non-null    float64
#  25  city-L/100km       201 non-null    float64
#  26  horsepower-binned  200 non-null    object
#  27  diesel             201 non-null    int64
#  28  gas                201 non-null    int64
# dtypes: float64(11), int64(8), object(10)
# memory usage: 45.7+ KB

# %%
auto.drop('?', axis='columns', inplace=True)

# %%
auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
auto.shape
# Out:
# (201, 29)

# %%
auto.head(200)
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 195         -1                 74        volvo      turbo         four
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0    convertible          rwd           front        88.6  0.811148  ...
# 1    convertible          rwd           front        88.6  0.811148  ...
# 2      hatchback          rwd           front        94.5  0.822681  ...
# 3          sedan          fwd           front        99.8  0.848630  ...
# 4          sedan          4wd           front        99.4  0.848630  ...
# ..           ...          ...             ...         ...       ...  ...
# 195        wagon          rwd           front       104.3  0.907256  ...
# 196        sedan          rwd           front       109.1  0.907256  ...
# 197        sedan          rwd           front       109.1  0.907256  ...
# 198        sedan          rwd           front       109.1  0.907256  ...
# 199        sedan          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                  9.0       111.0    5000.0       21          27  13495.0
# 1                  9.0       111.0    5000.0       21          27  16500.0
# 2                  9.0       154.0    5000.0       19          26  16500.0
# 3                 10.0       102.0    5500.0       24          30  13950.0
# 4                  8.0       115.0    5500.0       18          22  17450.0
# ..                 ...         ...       ...      ...         ...      ...
# 195                7.5       162.0    5100.0       17          22  18950.0
# 196                9.5       114.0    5400.0       23          28  16845.0
# 197                8.7       160.0    5300.0       19          25  19045.0
# 198                8.8       134.0    5500.0       18          23  21485.0
# 199               23.0       106.0    4800.0       26          27  22470.0
#
#     city-L/100km  horsepower-binned  diesel  gas
# 0      11.190476             Medium       0    1
# 1      11.190476             Medium       0    1
# 2      12.368421             Medium       0    1
# 3       9.791667             Medium       0    1
# 4      13.055556             Medium       0    1
# ..           ...                ...     ...  ...
# 195    13.823529               High       0    1
# 196    10.217391             Medium       0    1
# 197    12.368421               High       0    1
# 198    13.055556             Medium       0    1
# 199     9.038462             Medium       1    0
#
# [200 rows x 29 columns]

# %%
auto.columns.tolist()
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price',
#  'city-L/100km',
#  'horsepower-binned',
#  'diesel',
#  'gas']

# %%
#car_group = auto.groupby(["make","body-style"], as_index=False)['make'].count()
#car_group

# %%
auto.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 auto.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
sns.scatterplot(x='engine-size',y='price',data=auto)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
auto.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 auto.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
corr = auto.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 corr = auto.corr()
#       2 corr.style.background_gradient(cmap='coolwarm')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
df= auto.copy()

# %%
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0    convertible          rwd           front        88.6  0.811148  ...
# 1    convertible          rwd           front        88.6  0.811148  ...
# 2      hatchback          rwd           front        94.5  0.822681  ...
# 3          sedan          fwd           front        99.8  0.848630  ...
# 4          sedan          4wd           front        99.4  0.848630  ...
# ..           ...          ...             ...         ...       ...  ...
# 196        sedan          rwd           front       109.1  0.907256  ...
# 197        sedan          rwd           front       109.1  0.907256  ...
# 198        sedan          rwd           front       109.1  0.907256  ...
# 199        sedan          rwd           front       109.1  0.907256  ...
# 200        sedan          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                  9.0       111.0    5000.0       21          27  13495.0
# 1                  9.0       111.0    5000.0       21          27  16500.0
# 2                  9.0       154.0    5000.0       19          26  16500.0
# 3                 10.0       102.0    5500.0       24          30  13950.0
# 4                  8.0       115.0    5500.0       18          22  17450.0
# ..                 ...         ...       ...      ...         ...      ...
# 196                9.5       114.0    5400.0       23          28  16845.0
# 197                8.7       160.0    5300.0       19          25  19045.0
# 198                8.8       134.0    5500.0       18          23  21485.0
# 199               23.0       106.0    4800.0       26          27  22470.0
# 200                9.5       114.0    5400.0       19          25  22625.0
#
#     city-L/100km  horsepower-binned  diesel  gas
# 0      11.190476             Medium       0    1
# 1      11.190476             Medium       0    1
# 2      12.368421             Medium       0    1
# 3       9.791667             Medium       0    1
# 4      13.055556             Medium       0    1
# ..           ...                ...     ...  ...
# 196    10.217391             Medium       0    1
# 197    12.368421               High       0    1
# 198    13.055556             Medium       0    1
# 199     9.038462             Medium       1    0
# 200    12.368421             Medium       0    1
#
# [201 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0    convertible          rwd           front        88.6  0.811148  ...
# 1    convertible          rwd           front        88.6  0.811148  ...
# 2      hatchback          rwd           front        94.5  0.822681  ...
# 3          sedan          fwd           front        99.8  0.848630  ...
# 4          sedan          4wd           front        99.4  0.848630  ...
# ..           ...          ...             ...         ...       ...  ...
# 196        sedan          rwd           front       109.1  0.907256  ...
# 197        sedan          rwd           front       109.1  0.907256  ...
# 198        sedan          rwd           front       109.1  0.907256  ...
# 199        sedan          rwd           front       109.1  0.907256  ...
# 200        sedan          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                  9.0       111.0    5000.0       21          27  13495.0
# 1                  9.0       111.0    5000.0       21          27  16500.0
# 2                  9.0       154.0    5000.0       19          26  16500.0
# 3                 10.0       102.0    5500.0       24          30  13950.0
# 4                  8.0       115.0    5500.0       18          22  17450.0
# ..                 ...         ...       ...      ...         ...      ...
# 196                9.5       114.0    5400.0       23          28  16845.0
# 197                8.7       160.0    5300.0       19          25  19045.0
# 198                8.8       134.0    5500.0       18          23  21485.0
# 199               23.0       106.0    4800.0       26          27  22470.0
# 200                9.5       114.0    5400.0       19          25  22625.0
#
#     city-L/100km  horsepower-binned  diesel  gas
# 0      11.190476             Medium       0    1
# 1      11.190476             Medium       0    1
# 2      12.368421             Medium       0    1
# 3       9.791667             Medium       0    1
# 4      13.055556             Medium       0    1
# ..           ...                ...     ...  ...
# 196    10.217391             Medium       0    1
# 197    12.368421               High       0    1
# 198    13.055556             Medium       0    1
# 199     9.038462             Medium       1    0
# 200    12.368421             Medium       0    1
#
# [201 rows x 29 columns]

# %%
df_numeric= df.select_dtypes('number')

# %%
df_numeric.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# 0    5000.0        21           27  13495.0     11.190476       0    1
# 1    5000.0        21           27  16500.0     11.190476       0    1
# 2    5000.0        19           26  16500.0     12.368421       0    1
# 3    5500.0        24           30  13950.0      9.791667       0    1
# 4    5500.0        18           22  17450.0     13.055556       0    1

# %%
df_numeric.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
# city-L/100km        0.066171           0.238567    0.476153  0.657373
# diesel             -0.196735          -0.101546    0.307237  0.211187
# gas                 0.196735           0.101546   -0.307237 -0.211187
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188829 -0.062704     0.167562     0.209523 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615077 -0.087027     0.757976     0.822676  0.566936
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
# city-L/100km       0.673363  0.003811     0.785353     0.745059  0.554610
# diesel             0.244356  0.281578     0.221046     0.070779  0.054458
# gas               -0.244356 -0.281578    -0.221046    -0.070779 -0.054458
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008245          -0.182196    0.075819  0.279740
# normalized-losses  0.055563          -0.114713    0.217299  0.239543
# wheel-base         0.158502           0.250313    0.371147 -0.360305
# length             0.124139           0.159733    0.579821 -0.285970
# width              0.188829           0.189867    0.615077 -0.245800
# height            -0.062704           0.259737   -0.087027 -0.309974
# curb-weight        0.167562           0.156433    0.757976 -0.279361
# engine-size        0.209523           0.028889    0.822676 -0.256733
# bore              -0.055390           0.001263    0.566936 -0.267392
# stroke             1.000000           0.187923    0.098462 -0.065713
# compression-ratio  0.187923           1.000000   -0.214514 -0.435780
# horsepower         0.098462          -0.214514    1.000000  0.107885
# peak-rpm          -0.065713          -0.435780    0.107885  1.000000
# city-mpg          -0.034696           0.331425   -0.822214 -0.115413
# highway-mpg       -0.035201           0.268465   -0.804575 -0.058598
# price              0.082310           0.071107    0.809575 -0.101616
# city-L/100km       0.037300          -0.299372    0.889488  0.115830
# diesel             0.241303           0.985231   -0.169053 -0.475812
# gas               -0.241303          -0.985231    0.169053  0.475812
#
#                    city-mpg  highway-mpg     price  city-L/100km    diesel  \
# symboling         -0.035527     0.036233 -0.082391      0.066171 -0.196735
# normalized-losses -0.225016    -0.181877  0.133999      0.238567 -0.101546
# wheel-base        -0.470606    -0.543304  0.584642      0.476153  0.307237
# length            -0.665192    -0.698142  0.690628      0.657373  0.211187
# width             -0.633531    -0.680635  0.751265      0.673363  0.244356
# height            -0.049800    -0.104812  0.135486      0.003811  0.281578
# curb-weight       -0.749543    -0.794889  0.834415      0.785353  0.221046
# engine-size       -0.650546    -0.679571  0.872335      0.745059  0.070779
# bore              -0.582027    -0.591309  0.543155      0.554610  0.054458
# stroke            -0.034696    -0.035201  0.082310      0.037300  0.241303
# compression-ratio  0.331425     0.268465  0.071107     -0.299372  0.985231
# horsepower        -0.822214    -0.804575  0.809575      0.889488 -0.169053
# peak-rpm          -0.115413    -0.058598 -0.101616      0.115830 -0.475812
# city-mpg           1.000000     0.972044 -0.686571     -0.949713  0.265676
# highway-mpg        0.972044     1.000000 -0.704692     -0.930028  0.198690
# price             -0.686571    -0.704692  1.000000      0.789898  0.110326
# city-L/100km      -0.949713    -0.930028  0.789898      1.000000 -0.241282
# diesel             0.265676     0.198690  0.110326     -0.241282  1.000000
# gas               -0.265676    -0.198690 -0.110326      0.241282 -1.000000
#
#                         gas
# symboling          0.196735
# normalized-losses  0.101546
# wheel-base        -0.307237
# length            -0.211187
# width             -0.244356
# height            -0.281578
# curb-weight       -0.221046
# engine-size       -0.070779
# bore              -0.054458
# stroke            -0.241303
# compression-ratio -0.985231
# horsepower         0.169053
# peak-rpm           0.475812
# city-mpg          -0.265676
# highway-mpg       -0.198690
# price             -0.110326
# city-L/100km       0.241282
# diesel            -1.000000
# gas                1.000000

# %%
corr = df_numeric.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1d79b_row0_col0, #T_1d79b_row1_col1, #T_1d79b_row2_col2, #T_1d79b_row3_col3, #T_1d79b_row4_col4, #T_1d79b_row5_col5, #T_1d79b_row6_col6, #T_1d79b_row7_col7, #T_1d79b_row8_col8, #T_1d79b_row9_col9, #T_1d79b_row10_col10, #T_1d79b_row11_col11, #T_1d79b_row12_col12, #T_1d79b_row13_col13, #T_1d79b_row14_col14, #T_1d79b_row15_col15, #T_1d79b_row16_col16, #T_1d79b_row17_col17, #T_1d79b_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1d79b_row0_col1, #T_1d79b_row1_col16, #T_1d79b_row6_col17, #T_1d79b_row18_col16 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_1d79b_row0_col2, #T_1d79b_row10_col18, #T_1d79b_row13_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1d79b_row0_col3, #T_1d79b_row4_col0, #T_1d79b_row17_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1d79b_row0_col4, #T_1d79b_row12_col4, #T_1d79b_row15_col9, #T_1d79b_row18_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1d79b_row0_col5, #T_1d79b_row5_col0, #T_1d79b_row5_col1, #T_1d79b_row13_col11, #T_1d79b_row13_col16, #T_1d79b_row14_col2, #T_1d79b_row14_col3, #T_1d79b_row14_col4, #T_1d79b_row14_col6, #T_1d79b_row14_col7, #T_1d79b_row14_col8, #T_1d79b_row14_col15, #T_1d79b_row16_col13, #T_1d79b_row16_col14, #T_1d79b_row17_col12, #T_1d79b_row17_col18, #T_1d79b_row18_col9, #T_1d79b_row18_col10, #T_1d79b_row18_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1d79b_row0_col6, #T_1d79b_row1_col2, #T_1d79b_row9_col1, #T_1d79b_row9_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_1d79b_row0_col7, #T_1d79b_row9_col8, #T_1d79b_row18_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_1d79b_row0_col8, #T_1d79b_row7_col0, #T_1d79b_row14_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_1d79b_row0_col9, #T_1d79b_row8_col13, #T_1d79b_row10_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1d79b_row0_col10, #T_1d79b_row5_col11, #T_1d79b_row7_col5, #T_1d79b_row11_col0, #T_1d79b_row17_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_1d79b_row0_col11, #T_1d79b_row5_col15 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1d79b_row0_col12, #T_1d79b_row10_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1d79b_row0_col13, #T_1d79b_row1_col7, #T_1d79b_row8_col5, #T_1d79b_row9_col13 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_1d79b_row0_col14 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_1d79b_row0_col15, #T_1d79b_row13_col18, #T_1d79b_row17_col16 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1d79b_row0_col16, #T_1d79b_row10_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_1d79b_row0_col17, #T_1d79b_row14_col18, #T_1d79b_row16_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1d79b_row0_col18, #T_1d79b_row14_col17 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_1d79b_row1_col0, #T_1d79b_row2_col11, #T_1d79b_row2_col17 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_1d79b_row1_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1d79b_row1_col4, #T_1d79b_row9_col2, #T_1d79b_row10_col15 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_1d79b_row1_col5, #T_1d79b_row15_col14 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1d79b_row1_col6, #T_1d79b_row8_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_1d79b_row1_col8, #T_1d79b_row7_col1, #T_1d79b_row12_col15 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_1d79b_row1_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1d79b_row1_col10 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1d79b_row1_col11 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_1d79b_row1_col12, #T_1d79b_row5_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_1d79b_row1_col13, #T_1d79b_row10_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1d79b_row1_col14, #T_1d79b_row6_col18, #T_1d79b_row11_col10, #T_1d79b_row17_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1d79b_row1_col15, #T_1d79b_row5_col16 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_1d79b_row1_col17, #T_1d79b_row12_col14 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_1d79b_row1_col18, #T_1d79b_row17_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_1d79b_row2_col0, #T_1d79b_row13_col15, #T_1d79b_row14_col11, #T_1d79b_row14_col16 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col4, #T_1d79b_row6_col16, #T_1d79b_row11_col15 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col5, #T_1d79b_row5_col2, #T_1d79b_row12_col18 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_1d79b_row2_col6, #T_1d79b_row16_col15 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col7, #T_1d79b_row8_col7 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_1d79b_row2_col8 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_1d79b_row2_col9, #T_1d79b_row13_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1d79b_row2_col10, #T_1d79b_row4_col17, #T_1d79b_row17_col13 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_1d79b_row2_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col13, #T_1d79b_row12_col3, #T_1d79b_row13_col12 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_1d79b_row2_col14 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_1d79b_row2_col15, #T_1d79b_row3_col8 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_1d79b_row2_col16, #T_1d79b_row7_col8, #T_1d79b_row8_col15, #T_1d79b_row15_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_1d79b_row2_col18, #T_1d79b_row4_col9, #T_1d79b_row6_col1, #T_1d79b_row10_col9, #T_1d79b_row16_col10, #T_1d79b_row18_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_1d79b_row3_col0, #T_1d79b_row3_col14, #T_1d79b_row12_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col1, #T_1d79b_row12_col6, #T_1d79b_row14_col5, #T_1d79b_row18_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_1d79b_row3_col2, #T_1d79b_row6_col4 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col4, #T_1d79b_row4_col3, #T_1d79b_row7_col6 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col5 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_1d79b_row3_col6, #T_1d79b_row6_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col7 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1d79b_row3_col10, #T_1d79b_row6_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_1d79b_row3_col11 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col12 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col15, #T_1d79b_row15_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col16 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_1d79b_row3_col17 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_1d79b_row3_col18 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_1d79b_row4_col1, #T_1d79b_row10_col11, #T_1d79b_row10_col16 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1d79b_row4_col2, #T_1d79b_row16_col6 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_1d79b_row4_col5, #T_1d79b_row6_col5, #T_1d79b_row17_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_1d79b_row4_col6, #T_1d79b_row7_col15, #T_1d79b_row15_col7 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_1d79b_row4_col7, #T_1d79b_row7_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_1d79b_row4_col8, #T_1d79b_row15_col8 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1d79b_row4_col10, #T_1d79b_row9_col10, #T_1d79b_row11_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_1d79b_row4_col11 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_1
